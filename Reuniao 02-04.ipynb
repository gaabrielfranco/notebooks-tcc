# %% [markdown]
# # Script reunião 02/04
#
# ## Poda da outliers

# %% [markdown]
# 1) Estão sendo podados muitos outliers, então usar o IQR para fazer a poda
# 2) Refazer todos os experimentos já feitos com os novos dados

# %% [markdown]
# ### Summary about outliers
#
# Number of outliers =  2862
# Number of outliers in 1, ..., 9 attributes:
# [2463, 307, 64, 19, 8, 1, 0, 0, 0]
#
# Number of outliers per attribute:
# kills: 237
# deaths: 397
# assists: 392
# denies: 437
# gpm: 56
# hd: 563
# hh: 1177
# lh: 85
# xpm: 47

# %% [markdown]
# ## Sobre o score f = (K + A) / D
#
# 1) Qual a distribuição dessa variável dentro de cada cluster?

# %%
from IPython.display import Image

Image(filename='data/all_3_C1_dist_norm.png')

# %%
Image(filename='data/all_3_C2_dist_norm.png')

# %%
Image(filename='data/all_3_C3_dist_norm.png')

# %%
Image(filename='data/f-analysis-pruned.png')

# %% [markdown]
# * Mostrar output_plot_metric

# %% [markdown]
# ## Sobre os centroids
#
# 1) Que tipo de jogador seria o centroid de cada cluster?
# 2) Que tipo de jogador (dentro de um cluster específico) seria o jogador que está mais longe do centroid?
# 3) Selecionar alguns usuários aleatoriamente dentro de cada cluster para ter uma ideia do que está acontecendo

# %% [markdown]
# * Mostrar output_cluster_evaluation/cluster_descrition_pruned.txt.
# * Mostrar também output_cluster_evaluation/distance_eval_pruned.txt

# %%
Image(filename='data/all_3_C1.png')

# %%
Image(filename='data/all_3_C2.png')

# %%
Image(filename='data/all_3_C3.png')

# %% [markdown]
# * Mostrar output_cluster_evaluation/plots

# %% [markdown]
# ## PCA
#
# 1) Utilizar o PCA para reduzir a dimensionalidade dos dados e plotar os dados para visualização

# %%
Image(filename='data/PCA_3_dimension.png')

# %%
Image(filename='data/PCA_2_dimension.png')

# %%
Image(filename='data/PCA_1_dimension.png')

# %%
Image(filename='data/Variance.png')

# %% [markdown]
# ## Outros pontos
#
# 1) Meus horários na semana que vem e na próxima
# 2) Documentação
